# %%
import pandas as pd

pd.__version__
# Out:
# '1.3.1'

# %% [markdown]
# ## Series

# %%
pd.Series(data = [1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
data2 = pd.DataFrame(data=
                    {"Nama" : ["Ahmad","Joko","Adi"],
                    "Umur" : [12,13,15],
                    "Kelas" : [6,7,8]})

data2
# Out:
#     Nama  Umur  Kelas
# 0  Ahmad    12      6
# 1   Joko    13      7
# 2    Adi    15      8

# %%
df = {
    'col_1' : [3,2,1,0],
    'col2' : ['a','b','c','d']
}

df1 = pd.DataFrame(df)
df1
# Out:
#    col_1 col2
# 0      3    a
# 1      2    b
# 2      1    c
# 3      0    d

# %%
df2 = pd.DataFrame.from_dict(df, orient='index',
                            columns=['A','B','C','D'])

df2
# Out:
#        A  B  C  D
# col_1  3  2  1  0
# col2   a  b  c  d

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# ## Exercise 1

# %%
df = pd.DataFrame(data = 
                 {
                     "Age" : [24,13,53],
                     "Location" : ['New York', 'Paris', 'Berlin'],
                     "Name" : ['John', 'Anna', 'Peter']
                 })

df
# Out:
#    Age  Location   Name
# 0   24  New York   John
# 1   13     Paris   Anna
# 2   53    Berlin  Peter

# %%
df.rename(columns={'Location': 'City'})
# Out:
#    Age      City   Name
# 0   24  New York   John
# 1   13     Paris   Anna
# 2   53    Berlin  Peter

# %%
dataset = pd.read_csv('My Uber Drives - 2016.csv')
dataset.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
dataset.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
data = pd.read_csv('https://storage.googleapis.com/data_science_training/My%20Uber%20Drives%20-%202016.csv')
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
dataset.shape
# Out:
# (1156, 7)

# %%
dataset.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
dataset.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %% [markdown]
# ## Convert Tipe Data

# %%
dataset1 = pd.DataFrame({"Cost":["5","5","7"],"Amount":[11,12,13],"Date": ["11-10-2020","12-10-2020","13-10-2020"]})
dataset1
# Out:
#   Cost  Amount        Date
# 0    5      11  11-10-2020
# 1    5      12  12-10-2020
# 2    7      13  13-10-2020

# %%
dataset1.dtypes
# Out:
# Cost      object
# Amount     int64
# Date      object
# dtype: object

# %%
dataset1['Date'] = pd.to_datetime(dataset1['Date'])
dataset1.dtypes
# Out:
# Cost              object
# Amount             int64
# Date      datetime64[ns]
# dtype: object

# %%
dataset1["Cost"] = pd.to_numeric(dataset1["Cost"])
dataset1.dtypes
# Out:
# Cost               int64
# Amount             int64
# Date      datetime64[ns]
# dtype: object

# %%
dataset1
# Out:
#    Cost  Amount       Date
# 0     5      11 2020-11-10
# 1     5      12 2020-12-10
# 2     7      13 2020-10-13

# %% [markdown]
# ## Applying to our Dataframe

# %%
pd.to_datetime(dataset["START_DATE*"], format='%m/%d/%Y %H:%M', errors='coerce')
# Out:
# 0      2016-01-01 21:11:00
# 1      2016-01-02 01:25:00
# 2      2016-01-02 20:25:00
# 3      2016-01-05 17:31:00
# 4      2016-01-06 14:42:00
#                ...
# 1151   2016-12-31 13:24:00
# 1152   2016-12-31 15:03:00
# 1153   2016-12-31 21:32:00
# 1154   2016-12-31 22:08:00
# 1155                   NaT
# Name: START_DATE*, Length: 1156, dtype: datetime64[ns]

# %%
dataset.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
dataset['START_DATE*'] = pd.to_datetime(dataset["START_DATE*"], format='%m/%d/%Y %H:%M', errors='coerce')
dataset['START_DATE*']
# Out:
# 0      2016-01-01 21:11:00
# 1      2016-01-02 01:25:00
# 2      2016-01-02 20:25:00
# 3      2016-01-05 17:31:00
# 4      2016-01-06 14:42:00
#                ...
# 1151   2016-12-31 13:24:00
# 1152   2016-12-31 15:03:00
# 1153   2016-12-31 21:32:00
# 1154   2016-12-31 22:08:00
# 1155                   NaT
# Name: START_DATE*, Length: 1156, dtype: datetime64[ns]

# %%
dataset.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
dataset['END_DATE*'] = pd.to_datetime(dataset["END_DATE*"], format='%m/%d/%Y %H:%M', errors='coerce')
dataset['END_DATE*']
# Out:
# 0      2016-01-01 21:17:00
# 1      2016-01-02 01:37:00
# 2      2016-01-02 20:38:00
# 3      2016-01-05 17:45:00
# 4      2016-01-06 15:49:00
#                ...
# 1151   2016-12-31 13:42:00
# 1152   2016-12-31 15:38:00
# 1153   2016-12-31 21:50:00
# 1154   2016-12-31 23:51:00
# 1155                   NaT
# Name: END_DATE*, Length: 1156, dtype: datetime64[ns]

# %%
dataset.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
dataset.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
dataset.describe(include='all')
# Out:
# C:\Users\Vulcan\AppData\Local\Temp/ipykernel_7288/1519417330.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dataset.describe(include='all')
#                 START_DATE*            END_DATE* CATEGORY* START* STOP*  \
# count                  1155                 1155      1155   1155  1155
# unique                 1154                 1154         2    177   188
# top     2016-06-28 23:34:00  2016-06-28 23:59:00  Business   Cary  Cary
# freq                      2                    2      1078    201   203
# first   2016-01-01 21:11:00  2016-01-01 21:17:00       NaN    NaN   NaN
# last    2016-12-31 22:08:00  2016-12-31 23:51:00       NaN    NaN   NaN
# mean                    NaN                  NaN       NaN    NaN   NaN
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   datetime64[ns]
#  1   END_DATE*    1155 non-null   datetime64[ns]
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
dataset['PURPOSE*'].isnull().sum()
# Out:
# 503

# %%
dataset['START*'].value_counts()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: START*, Length: 177, dtype: int64

# %% [markdown]
# # Exercise 2

# %%
data_umur = pd.DataFrame(data=
                    {"Nama" : ["Ahmad","Joko","Adi"],
                    "Umur" : ["12","13","15"],
                    "Kelas" : [6,7,8]})

data_umur
# Out:
#     Nama Umur  Kelas
# 0  Ahmad   12      6
# 1   Joko   13      7
# 2    Adi   15      8

# %%
data_umur.dtypes
# Out:
# Nama     object
# Umur     object
# Kelas     int64
# dtype: object

# %%
data_umur['Umur'] = pd.to_numeric(data_umur['Umur'])
data_umur['Umur']
# Out:
# 0    12
# 1    13
# 2    15
# Name: Umur, dtype: int64

# %%
data_umur.dtypes
# Out:
# Nama     object
# Umur      int64
# Kelas     int64
# dtype: object

# %% [markdown]
# ## Data Titanic

# %%
data_titanic = pd.read_csv('Titanic.csv')

# %%
data_titanic.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
data_titanic.tail()
# Out:
#                         Name PClass   Age   Sex  Survived
# 1308      Zakarian, Mr Artun    3rd  27.0  male         0
# 1309  Zakarian, Mr Maprieder    3rd  26.0  male         0
# 1310        Zenni, Mr Philip    3rd  22.0  male         0
# 1311        Lievens, Mr Rene    3rd  24.0  male         0
# 1312          Zimmerman, Leo    3rd  29.0  male         0

# %%
data_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1312 non-null   object
#  2   Age       756 non-null    float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 51.4+ KB

# %%
data_titanic.size
# Out:
# 6565

# %%
data_titanic.shape
# Out:
# (1313, 5)

# %% [markdown]
# # Data Titanic Indonesia AI

# %%
titanic = pd.read_csv('train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
col = {'PassengerId' : 'ID',
      'Embarked' : 'Port'}
titanic.rename(columns=col, inplace=True)
titanic
# Out:
#       ID  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
titanic.describe()
# Out:
#                ID    Survived      Pclass         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   446.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    223.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    446.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    668.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic['Port'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Port, dtype: int64

# %% [markdown]
# # Data manipulation

# %% [markdown]
# ## Selecting/Indexing
#
# ## - iloc secara index
# ## - loc secara label

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit

# %% [markdown]
# ## Positional indexing

# %%
dataset.iloc[0:3, [1,3]]
# Out:
#             END_DATE*       START*
# 0 2016-01-01 21:17:00  Fort Pierce
# 1 2016-01-02 01:37:00  Fort Pierce
# 2 2016-01-02 20:38:00  Fort Pierce

# %%
dataset.iloc[:, 3:6]
# Out:
#                 START*             STOP*   MILES*
# 0          Fort Pierce       Fort Pierce      5.1
# 1          Fort Pierce       Fort Pierce      5.0
# 2          Fort Pierce       Fort Pierce      4.8
# 3          Fort Pierce       Fort Pierce      4.7
# 4          Fort Pierce   West Palm Beach     63.7
# ...                ...               ...      ...
# 1151           Kar?chi  Unknown Location      3.9
# 1152  Unknown Location  Unknown Location     16.2
# 1153        Katunayake           Gampaha      6.4
# 1154           Gampaha         Ilukwatta     48.2
# 1155               NaN               NaN  12204.7
#
# [1156 rows x 3 columns]

# %%
dataset.iloc[1:3,3:6]
# Out:
#         START*        STOP*  MILES*
# 1  Fort Pierce  Fort Pierce     5.0
# 2  Fort Pierce  Fort Pierce     4.8

# %% [markdown]
# ## Label Indexing

# %%
dataset.loc[0:5, :'START*']
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach

# %%
dataset.loc[:, ['START_DATE*','MILES*']]
# Out:
#              START_DATE*   MILES*
# 0    2016-01-01 21:11:00      5.1
# 1    2016-01-02 01:25:00      5.0
# 2    2016-01-02 20:25:00      4.8
# 3    2016-01-05 17:31:00      4.7
# 4    2016-01-06 14:42:00     63.7
# ...                  ...      ...
# 1151 2016-12-31 13:24:00      3.9
# 1152 2016-12-31 15:03:00     16.2
# 1153 2016-12-31 21:32:00      6.4
# 1154 2016-12-31 22:08:00     48.2
# 1155                 NaT  12204.7
#
# [1156 rows x 2 columns]

# %%
a = data.loc[:, 'START*']

type(a)
# Out:
# pandas.core.series.Series

# %%
b = data.loc[:, ['START*']]

type(b)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ## Akses 10 Data Teratas, LOC dan ILOC

# %%
dataset.loc[:9, ['START_DATE*','START*','STOP*']]
# Out:
#           START_DATE*           START*            STOP*
# 0 2016-01-01 21:11:00      Fort Pierce      Fort Pierce
# 1 2016-01-02 01:25:00      Fort Pierce      Fort Pierce
# 2 2016-01-02 20:25:00      Fort Pierce      Fort Pierce
# 3 2016-01-05 17:31:00      Fort Pierce      Fort Pierce
# 4 2016-01-06 14:42:00      Fort Pierce  West Palm Beach
# 5 2016-01-06 17:15:00  West Palm Beach  West Palm Beach
# 6 2016-01-06 17:30:00  West Palm Beach       Palm Beach
# 7 2016-01-07 13:27:00             Cary             Cary
# 8 2016-01-10 08:05:00             Cary      Morrisville
# 9 2016-01-10 12:17:00          Jamaica         New York

# %%
dataset.iloc[:10, [0,3,4]]
# Out:
#           START_DATE*           START*            STOP*
# 0 2016-01-01 21:11:00      Fort Pierce      Fort Pierce
# 1 2016-01-02 01:25:00      Fort Pierce      Fort Pierce
# 2 2016-01-02 20:25:00      Fort Pierce      Fort Pierce
# 3 2016-01-05 17:31:00      Fort Pierce      Fort Pierce
# 4 2016-01-06 14:42:00      Fort Pierce  West Palm Beach
# 5 2016-01-06 17:15:00  West Palm Beach  West Palm Beach
# 6 2016-01-06 17:30:00  West Palm Beach       Palm Beach
# 7 2016-01-07 13:27:00             Cary             Cary
# 8 2016-01-10 08:05:00             Cary      Morrisville
# 9 2016-01-10 12:17:00          Jamaica         New York

# %% [markdown]
# ## Akses 10 Data Terbawah, LOC dan ILOC

# %%
dataset.loc[1146:, ['START_DATE*','START*','STOP*']]
# Out:
#              START_DATE*            START*             STOP*
# 1146 2016-12-30 11:31:00           Kar?chi           Kar?chi
# 1147 2016-12-30 15:41:00           Kar?chi           Kar?chi
# 1148 2016-12-30 16:45:00           Kar?chi           Kar?chi
# 1149 2016-12-30 23:06:00           Kar?chi           Kar?chi
# 1150 2016-12-31 01:07:00           Kar?chi           Kar?chi
# 1151 2016-12-31 13:24:00           Kar?chi  Unknown Location
# 1152 2016-12-31 15:03:00  Unknown Location  Unknown Location
# 1153 2016-12-31 21:32:00        Katunayake           Gampaha
# 1154 2016-12-31 22:08:00           Gampaha         Ilukwatta
# 1155                 NaT               NaN               NaN

# %%
dataset.iloc[-10:, [0,3,4]]
# Out:
#              START_DATE*            START*             STOP*
# 1146 2016-12-30 11:31:00           Kar?chi           Kar?chi
# 1147 2016-12-30 15:41:00           Kar?chi           Kar?chi
# 1148 2016-12-30 16:45:00           Kar?chi           Kar?chi
# 1149 2016-12-30 23:06:00           Kar?chi           Kar?chi
# 1150 2016-12-31 01:07:00           Kar?chi           Kar?chi
# 1151 2016-12-31 13:24:00           Kar?chi  Unknown Location
# 1152 2016-12-31 15:03:00  Unknown Location  Unknown Location
# 1153 2016-12-31 21:32:00        Katunayake           Gampaha
# 1154 2016-12-31 22:08:00           Gampaha         Ilukwatta
# 1155                 NaT               NaN               NaN

# %% [markdown]
# # Filtering

# %%
miles_up10 = dataset.loc[dataset['MILES*'] > 10, ['MILES*']]
miles_up10
# Out:
#        MILES*
# 4        63.7
# 9        16.5
# 10       10.8
# 22       15.1
# 23       11.2
# ...       ...
# 1134     11.9
# 1144     12.9
# 1152     16.2
# 1154     48.2
# 1155  12204.7
#
# [316 rows x 1 columns]

# %%
miles_up10 = dataset.loc[dataset['MILES*'] > 10, ['START*']]
miles_up10
# Out:
#                 START*
# 4          Fort Pierce
# 9              Jamaica
# 10            New York
# 22            New York
# 23            Downtown
# ...                ...
# 1134  Unknown Location
# 1144  Unknown Location
# 1152  Unknown Location
# 1154           Gampaha
# 1155               NaN
#
# [316 rows x 1 columns]

# %%
# data kosong
df2 = miles_up10.loc[0:3]
df2
# Out:
# Empty DataFrame
# Columns: [START*]
# Index: []

# %%
# data kosong
df2 = miles_up10.iloc[0:3]
df2
# Out:
#          START*
# 4   Fort Pierce
# 9       Jamaica
# 10     New York

# %%
# Menampilkan semua kolom tanpa parameter
dataset.loc[dataset['MILES*'] > 10]
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# 9    2016-01-10 12:17:00 2016-01-10 12:44:00  Business           Jamaica
# 10   2016-01-10 15:08:00 2016-01-10 15:51:00  Business          New York
# 22   2016-01-12 16:02:00 2016-01-12 17:00:00  Business          New York
# 23   2016-01-13 13:54:00 2016-01-13 14:07:00  Business          Downtown
# ...                  ...                 ...       ...               ...
# 1134 2016-12-29 11:28:00 2016-12-29 12:00:00  Business  Unknown Location
# 1144 2016-12-29 23:14:00 2016-12-29 23:47:00  Business  Unknown Location
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# ...

# %%
dataset.loc[dataset['START*'] == 'New York']
# Out:
#             START_DATE*           END_DATE* CATEGORY*    START*  \
# 10  2016-01-10 15:08:00 2016-01-10 15:51:00  Business  New York
# 22  2016-01-12 16:02:00 2016-01-12 17:00:00  Business  New York
# 106 2016-02-14 16:35:00 2016-02-14 17:02:00  Business  New York
# 423 2016-06-10 15:19:00 2016-06-10 16:28:00  Business  New York
#
#                 STOP*  MILES* PURPOSE*
# 10             Queens    10.8  Meeting
# 22      Queens County    15.1  Meeting
# 106  Long Island City    13.0  Meeting
# 423           Jamaica    16.3  Meeting

# %%
dataset.loc[dataset['START*'] == 'New York', ['MILES*','STOP*']]
# Out:
#      MILES*             STOP*
# 10     10.8            Queens
# 22     15.1     Queens County
# 106    13.0  Long Island City
# 423    16.3           Jamaica

# %%
st = dataset[dataset['START*'].isin(['Cary','Morrisville'])]
st.head(10)
# Out:
#            START_DATE*           END_DATE* CATEGORY*       START*  \
# 7  2016-01-07 13:27:00 2016-01-07 13:33:00  Business         Cary
# 8  2016-01-10 08:05:00 2016-01-10 08:25:00  Business         Cary
# 27 2016-01-15 00:41:00 2016-01-15 01:01:00  Business  Morrisville
# 28 2016-01-15 11:43:00 2016-01-15 12:03:00  Business         Cary
# 30 2016-01-18 14:55:00 2016-01-18 15:06:00  Business         Cary
# 34 2016-01-20 10:36:00 2016-01-20 11:11:00  Business         Cary
# 37 2016-01-21 14:25:00 2016-01-21 14:29:00  Business         Cary
# 38 2016-01-21 14:43:00 2016-01-21 14:51:00  Business         Cary
# 39 2016-01-21 16:01:00 2016-01-21 16:06:00  Business         Cary
# 43 2016-01-26 17:17:00 2016-01-26 17:22:00  Business         Cary
#
#           STOP*  MILES*         PURPOSE*
# 7          Cary     0.8          Meeting
# 8   Morrisville     8.3          Meeting
# 27         Cary     8.0  Errand/Supplies
# 28       Durham    10.4   Meal/Entertain
# ...

# %%
st.iloc[0:5, :]
# Out:
#            START_DATE*           END_DATE* CATEGORY*       START*  \
# 7  2016-01-07 13:27:00 2016-01-07 13:33:00  Business         Cary
# 8  2016-01-10 08:05:00 2016-01-10 08:25:00  Business         Cary
# 27 2016-01-15 00:41:00 2016-01-15 01:01:00  Business  Morrisville
# 28 2016-01-15 11:43:00 2016-01-15 12:03:00  Business         Cary
# 30 2016-01-18 14:55:00 2016-01-18 15:06:00  Business         Cary
#
#           STOP*  MILES*         PURPOSE*
# 7          Cary     0.8          Meeting
# 8   Morrisville     8.3          Meeting
# 27         Cary     8.0  Errand/Supplies
# 28       Durham    10.4   Meal/Entertain
# 30         Cary     4.8   Meal/Entertain

# %%
st.loc[0:5, :]
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
st
# Out:
#              START_DATE*           END_DATE* CATEGORY*       START*  \
# 7    2016-01-07 13:27:00 2016-01-07 13:33:00  Business         Cary
# 8    2016-01-10 08:05:00 2016-01-10 08:25:00  Business         Cary
# 27   2016-01-15 00:41:00 2016-01-15 01:01:00  Business  Morrisville
# 28   2016-01-15 11:43:00 2016-01-15 12:03:00  Business         Cary
# 30   2016-01-18 14:55:00 2016-01-18 15:06:00  Business         Cary
# ...                  ...                 ...       ...          ...
# 1050 2016-12-14 16:52:00 2016-12-14 17:10:00  Business         Cary
# 1051 2016-12-14 17:22:00 2016-12-14 17:34:00  Business         Cary
# 1052 2016-12-14 17:50:00 2016-12-14 18:00:00  Business         Cary
# 1053 2016-12-14 20:24:00 2016-12-14 20:40:00  Business  Morrisville
# 1054 2016-12-15 14:20:00 2016-12-15 14:54:00  Business         Cary
#
#             STOP*  MILES*         PURPOSE*
# 7            Cary     0.8          Meeting
# 8     Morrisville     8.3          Meeting
# ...

# %% [markdown]
# ## Mengurutkan data dan indexnya

# %%
st.reset_index()
# Out:
#      index         START_DATE*           END_DATE* CATEGORY*       START*  \
# 0        7 2016-01-07 13:27:00 2016-01-07 13:33:00  Business         Cary
# 1        8 2016-01-10 08:05:00 2016-01-10 08:25:00  Business         Cary
# 2       27 2016-01-15 00:41:00 2016-01-15 01:01:00  Business  Morrisville
# 3       28 2016-01-15 11:43:00 2016-01-15 12:03:00  Business         Cary
# 4       30 2016-01-18 14:55:00 2016-01-18 15:06:00  Business         Cary
# ..     ...                 ...                 ...       ...          ...
# 281   1050 2016-12-14 16:52:00 2016-12-14 17:10:00  Business         Cary
# 282   1051 2016-12-14 17:22:00 2016-12-14 17:34:00  Business         Cary
# 283   1052 2016-12-14 17:50:00 2016-12-14 18:00:00  Business         Cary
# 284   1053 2016-12-14 20:24:00 2016-12-14 20:40:00  Business  Morrisville
# 285   1054 2016-12-15 14:20:00 2016-12-15 14:54:00  Business         Cary
#
#            STOP*  MILES*         PURPOSE*
# ...

# %%
st.reset_index(drop = True)
# Out:
#             START_DATE*           END_DATE* CATEGORY*       START*  \
# 0   2016-01-07 13:27:00 2016-01-07 13:33:00  Business         Cary
# 1   2016-01-10 08:05:00 2016-01-10 08:25:00  Business         Cary
# 2   2016-01-15 00:41:00 2016-01-15 01:01:00  Business  Morrisville
# 3   2016-01-15 11:43:00 2016-01-15 12:03:00  Business         Cary
# 4   2016-01-18 14:55:00 2016-01-18 15:06:00  Business         Cary
# ..                  ...                 ...       ...          ...
# 281 2016-12-14 16:52:00 2016-12-14 17:10:00  Business         Cary
# 282 2016-12-14 17:22:00 2016-12-14 17:34:00  Business         Cary
# 283 2016-12-14 17:50:00 2016-12-14 18:00:00  Business         Cary
# 284 2016-12-14 20:24:00 2016-12-14 20:40:00  Business  Morrisville
# 285 2016-12-15 14:20:00 2016-12-15 14:54:00  Business         Cary
#
#            STOP*  MILES*         PURPOSE*
# 0           Cary     0.8          Meeting
# 1    Morrisville     8.3          Meeting
# ...

# %%
st
# Out:
#              START_DATE*           END_DATE* CATEGORY*       START*  \
# 7    2016-01-07 13:27:00 2016-01-07 13:33:00  Business         Cary
# 8    2016-01-10 08:05:00 2016-01-10 08:25:00  Business         Cary
# 27   2016-01-15 00:41:00 2016-01-15 01:01:00  Business  Morrisville
# 28   2016-01-15 11:43:00 2016-01-15 12:03:00  Business         Cary
# 30   2016-01-18 14:55:00 2016-01-18 15:06:00  Business         Cary
# ...                  ...                 ...       ...          ...
# 1050 2016-12-14 16:52:00 2016-12-14 17:10:00  Business         Cary
# 1051 2016-12-14 17:22:00 2016-12-14 17:34:00  Business         Cary
# 1052 2016-12-14 17:50:00 2016-12-14 18:00:00  Business         Cary
# 1053 2016-12-14 20:24:00 2016-12-14 20:40:00  Business  Morrisville
# 1054 2016-12-15 14:20:00 2016-12-15 14:54:00  Business         Cary
#
#             STOP*  MILES*         PURPOSE*
# 7            Cary     0.8          Meeting
# 8     Morrisville     8.3          Meeting
# ...

# %%
st.reset_index(inplace = True, drop = True)

# %%
st
# Out:
#             START_DATE*           END_DATE* CATEGORY*       START*  \
# 0   2016-01-07 13:27:00 2016-01-07 13:33:00  Business         Cary
# 1   2016-01-10 08:05:00 2016-01-10 08:25:00  Business         Cary
# 2   2016-01-15 00:41:00 2016-01-15 01:01:00  Business  Morrisville
# 3   2016-01-15 11:43:00 2016-01-15 12:03:00  Business         Cary
# 4   2016-01-18 14:55:00 2016-01-18 15:06:00  Business         Cary
# ..                  ...                 ...       ...          ...
# 281 2016-12-14 16:52:00 2016-12-14 17:10:00  Business         Cary
# 282 2016-12-14 17:22:00 2016-12-14 17:34:00  Business         Cary
# 283 2016-12-14 17:50:00 2016-12-14 18:00:00  Business         Cary
# 284 2016-12-14 20:24:00 2016-12-14 20:40:00  Business  Morrisville
# 285 2016-12-15 14:20:00 2016-12-15 14:54:00  Business         Cary
#
#            STOP*  MILES*         PURPOSE*
# 0           Cary     0.8          Meeting
# 1    Morrisville     8.3          Meeting
# ...

# %%
dataset.loc[dataset['START*'] == 'New York'] = 'Jakarta'

# %%
dataset.loc[dataset['START*'] == 'Jakarta']
# Out:
#     START_DATE* END_DATE* CATEGORY*   START*    STOP*   MILES* PURPOSE*
# 10      Jakarta   Jakarta   Jakarta  Jakarta  Jakarta  Jakarta  Jakarta
# 22      Jakarta   Jakarta   Jakarta  Jakarta  Jakarta  Jakarta  Jakarta
# 106     Jakarta   Jakarta   Jakarta  Jakarta  Jakarta  Jakarta  Jakarta
# 423     Jakarta   Jakarta   Jakarta  Jakarta  Jakarta  Jakarta  Jakarta

# %% [markdown]
# ## Sorting

# %%
data.sort_values(by=['MILES*'], ascending=False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %% [markdown]
# ## Conditionally Adding Column

# %%
import numpy as np
data['DISTANCE'] = np.where(data['MILES*'] >= 5, 'Long Trip', 'Short Trip')
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*    DISTANCE
# 0     5.1   Meal/Entertain   Long Trip
# 1     5.0              NaN   Long Trip
# 2     4.8  Errand/Supplies  Short Trip
# 3     4.7          Meeting  Short Trip
# 4    63.7   Customer Visit   Long Trip

# %%
data.loc[data['START*'] == 'New York']
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*   DISTANCE
# 10     10.8  Meeting  Long Trip
# 22     15.1  Meeting  Long Trip
# 106    13.0  Meeting  Long Trip
# 423    16.3  Meeting  Long Trip

# %%
data.replace('New York', 'Jakarta', inplace=True)

# %%
data.loc[data['START*'] == 'Jakarta']
# Out:
#          START_DATE*        END_DATE* CATEGORY*   START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  Jakarta            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  Jakarta     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  Jakarta  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  Jakarta           Jamaica
#
#      MILES* PURPOSE*   DISTANCE
# 10     10.8  Meeting  Long Trip
# 22     15.1  Meeting  Long Trip
# 106    13.0  Meeting  Long Trip
# 423    16.3  Meeting  Long Trip

# %%
data.sort_values(by=["MILES*"], ascending=False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*    DISTANCE
# 1155               NaN  12204.7              NaN   Long Trip
# ...

# %%
import numpy as np
data['DISTANCE'] = np.where(data['MILES*'] >= 5, 'Long Trip', 'Short Trip')
data.head()

# %%
data.groupby("START*")['MILES*'].agg(['sum'])
# Out:
#                    sum
# START*
# Agnew             11.1
# Almond            15.2
# Apex              90.8
# Arabi             17.0
# Arlington          4.9
# ...                ...
# West University    4.4
# Weston             8.0
# Westpark Place    37.1
# Whitebridge      273.4
# Winston Salem    133.6
#
# [177 rows x 1 columns]

# %% [markdown]
# ## Save DataFrame into CSV

# %%
st.to_csv('data_baru.csv', index=False)

# %%
st.replace('Business', 'First Class', inplace=True)
